# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv(r'NSE-TATAGLOBAL.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df2 = df.reset_index()['Close']

# %%
plt.plot(df2)

# %%
scaler = MinMaxScaler()

# %%
df2 = scaler.fit_transform(np.array(df2).reshape(-1,1))

# %%
df2.shape
# Out:
# (2035, 1)

# %%
train_size = int(len(df2)*0.65)
test_size = len(df2) - train_size
train_data,test_data = df2[0:train_size,:],df2[train_size:len(df2),:1]

# %%
def create_dataset(dataset, time_step = 1):
    dataX,dataY = [],[]
    for i in range(len(dataset)-time_step-1):
                   a = dataset[i:(i+time_step),0]
                   dataX.append(a)
                   dataY.append(dataset[i + time_step,0])
    return np.array(dataX),np.array(dataY)

# %%
time_step = 100
X_train,Y_train =  create_dataset(train_data,time_step)
X_test,Y_test =  create_dataset(test_data,time_step)

# %%
# checking values
print(X_train.shape)
print(X_train)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1221, 100)
# [[0.62418301 0.62214052 0.62622549 ... 0.83455882 0.86213235 0.85273693]
#  [0.62214052 0.62622549 0.63378268 ... 0.86213235 0.85273693 0.87111928]
#  [0.62622549 0.63378268 0.62234477 ... 0.85273693 0.87111928 0.84497549]
#  ...
#  [0.34517974 0.31781046 0.33047386 ... 0.2816585  0.27001634 0.26531863]
#  [0.31781046 0.33047386 0.32128268 ... 0.27001634 0.26531863 0.27389706]
#  [0.33047386 0.32128268 0.34007353 ... 0.26531863 0.27389706 0.25347222]]
# (612, 100)
# (612,)

# %%
# Creating and fitting LSTM model

model = Sequential()
model.add(LSTM(50,return_sequences = True,input_shape = (X_train.shape[1],1)))
model.add(LSTM(50,return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error',optimizer = 'adam')

# %%
model.summary()
model.fit(X_train,Y_train,validation_data = (X_test,Y_test),epochs = 100,batch_size = 64,verbose = 1)
# Here, the model has been trained for 100 epochs each with a batch size of 64.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 12s 291ms/step - loss: 0.0358 - val_loss: 0.0065
# Epoch 2/100
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 3/100
# 20/20 [==============================] - 5s 227ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 4/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 5/100
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 6/100
# 20/20 [==============================] - 5s 236ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 7/100
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 8/100
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 9/100
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 10/100
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0012 - val_loss: 9.5122e-04
# Epoch 11/100
# 20/20 [==============================] - 6s 296ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 12/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.0011 - val_loss: 9.9674e-04
# Epoch 13/100
# 20/20 [==============================] - 7s 329ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 14/100
# 20/20 [==============================] - 6s 310ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 15/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 16/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.0010 - val_loss: 6.7847e-04
# Epoch 17/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.0011 - val_loss: 6.3604e-04
# Epoch 18/100
# 20/20 [==============================] - 6s 299ms/step - loss: 9.7769e-04 - val_loss: 0.0010
# Epoch 19/100
# 20/20 [==============================] - 6s 296ms/step - loss: 9.9366e-04 - val_loss: 0.0012
# Epoch 20/100
# 20/20 [==============================] - 6s 302ms/step - loss: 9.9136e-04 - val_loss: 9.2322e-04
# Epoch 21/100
# 20/20 [==============================] - 7s 331ms/step - loss: 7.8097e-04 - val_loss: 7.0814e-04
# Epoch 22/100
# 20/20 [==============================] - 6s 313ms/step - loss: 8.1975e-04 - val_loss: 6.7147e-04
# Epoch 23/100
# 20/20 [==============================] - 6s 302ms/step - loss: 8.1932e-04 - val_loss: 6.1155e-04
# Epoch 24/100
# 20/20 [==============================] - 6s 313ms/step - loss: 7.3490e-04 - val_loss: 6.7497e-04
# Epoch 25/100
# 20/20 [==============================] - 6s 303ms/step - loss: 7.2529e-04 - val_loss: 7.1976e-04
# Epoch 26/100
# 20/20 [==============================] - 6s 300ms/step - loss: 7.0073e-04 - val_loss: 6.5394e-04
# Epoch 27/100
# 20/20 [==============================] - 6s 297ms/step - loss: 7.3983e-04 - val_loss: 6.1159e-04
# Epoch 28/100
# 20/20 [==============================] - 6s 309ms/step - loss: 7.2153e-04 - val_loss: 7.3987e-04
# Epoch 29/100
# 20/20 [==============================] - 6s 308ms/step - loss: 7.6993e-04 - val_loss: 6.3950e-04
# Epoch 30/100
# 20/20 [==============================] - 6s 296ms/step - loss: 6.9074e-04 - val_loss: 7.4194e-04
# Epoch 31/100
# 20/20 [==============================] - 6s 306ms/step - loss: 7.3285e-04 - val_loss: 7.7853e-04
# Epoch 32/100
# 20/20 [==============================] - 7s 337ms/step - loss: 6.2527e-04 - val_loss: 6.3869e-04
# Epoch 33/100
# 20/20 [==============================] - 6s 314ms/step - loss: 6.1159e-04 - val_loss: 7.6199e-04
# Epoch 34/100
# 20/20 [==============================] - 6s 287ms/step - loss: 5.8934e-04 - val_loss: 6.9951e-04
# Epoch 35/100
# 20/20 [==============================] - 6s 288ms/step - loss: 6.0672e-04 - val_loss: 5.1276e-04
# Epoch 36/100
# 20/20 [==============================] - 6s 296ms/step - loss: 7.4474e-04 - val_loss: 7.5189e-04
# Epoch 37/100
# 20/20 [==============================] - 6s 310ms/step - loss: 5.9424e-04 - val_loss: 5.8308e-04
# Epoch 38/100
# 20/20 [==============================] - 6s 308ms/step - loss: 5.5502e-04 - val_loss: 5.3424e-04
# Epoch 39/100
# 20/20 [==============================] - 6s 312ms/step - loss: 6.4082e-04 - val_loss: 5.5360e-04
# Epoch 40/100
# 20/20 [==============================] - 6s 296ms/step - loss: 5.4075e-04 - val_loss: 6.9277e-04
# Epoch 41/100
# 20/20 [==============================] - 6s 295ms/step - loss: 5.5432e-04 - val_loss: 6.5646e-04
# Epoch 42/100
# 20/20 [==============================] - 6s 319ms/step - loss: 6.1464e-04 - val_loss: 4.7494e-04
# Epoch 43/100
# 20/20 [==============================] - 6s 291ms/step - loss: 5.2973e-04 - val_loss: 6.5398e-04
# Epoch 44/100
# 20/20 [==============================] - 6s 297ms/step - loss: 5.1226e-04 - val_loss: 4.4135e-04
# Epoch 45/100
# 20/20 [==============================] - 6s 298ms/step - loss: 5.5020e-04 - val_loss: 4.2904e-04
# Epoch 46/100
# 20/20 [==============================] - 6s 295ms/step - loss: 5.8499e-04 - val_loss: 7.0552e-04
# Epoch 47/100
# 20/20 [==============================] - 6s 293ms/step - loss: 6.0047e-04 - val_loss: 5.2093e-04
# Epoch 48/100
# 20/20 [==============================] - 6s 290ms/step - loss: 5.0174e-04 - val_loss: 6.8278e-04
# Epoch 49/100
# 20/20 [==============================] - 6s 295ms/step - loss: 5.5513e-04 - val_loss: 4.2397e-04
# Epoch 50/100
# 20/20 [==============================] - 6s 295ms/step - loss: 4.7256e-04 - val_loss: 4.6940e-04
# Epoch 51/100
# 20/20 [==============================] - 6s 294ms/step - loss: 4.7486e-04 - val_loss: 3.8168e-04
# Epoch 52/100
# 20/20 [==============================] - 6s 292ms/step - loss: 4.9644e-04 - val_loss: 5.5619e-04
# Epoch 53/100
# 20/20 [==============================] - 6s 294ms/step - loss: 4.5583e-04 - val_loss: 5.0459e-04
# Epoch 54/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.0011 - val_loss: 4.0972e-04
# Epoch 55/100
# 20/20 [==============================] - 6s 299ms/step - loss: 5.4658e-04 - val_loss: 4.5143e-04
# Epoch 56/100
# 20/20 [==============================] - 6s 301ms/step - loss: 4.5091e-04 - val_loss: 4.2097e-04
# Epoch 57/100
# 20/20 [==============================] - 6s 301ms/step - loss: 4.5651e-04 - val_loss: 6.1114e-04
# Epoch 58/100
# 20/20 [==============================] - 6s 301ms/step - loss: 5.6907e-04 - val_loss: 4.5247e-04
# Epoch 59/100
# 20/20 [==============================] - 6s 302ms/step - loss: 4.2367e-04 - val_loss: 5.2464e-04
# Epoch 60/100
# 20/20 [==============================] - 6s 312ms/step - loss: 5.0113e-04 - val_loss: 3.6770e-04
# Epoch 61/100
# 20/20 [==============================] - 6s 303ms/step - loss: 5.7947e-04 - val_loss: 4.0572e-04
# Epoch 62/100
# 20/20 [==============================] - 6s 309ms/step - loss: 4.0019e-04 - val_loss: 3.7158e-04
# Epoch 63/100
# 20/20 [==============================] - 6s 304ms/step - loss: 3.9609e-04 - val_loss: 4.3635e-04
# Epoch 64/100
# 20/20 [==============================] - 6s 314ms/step - loss: 3.7350e-04 - val_loss: 3.8726e-04
# Epoch 65/100
# 20/20 [==============================] - 6s 305ms/step - loss: 3.6887e-04 - val_loss: 4.0180e-04
# Epoch 66/100
# 20/20 [==============================] - 6s 307ms/step - loss: 3.6518e-04 - val_loss: 3.3414e-04
# Epoch 67/100
# 20/20 [==============================] - 6s 300ms/step - loss: 3.9516e-04 - val_loss: 3.7953e-04
# Epoch 68/100
# 20/20 [==============================] - 6s 302ms/step - loss: 3.5721e-04 - val_loss: 3.6578e-04
# Epoch 69/100
# 20/20 [==============================] - 6s 306ms/step - loss: 3.4033e-04 - val_loss: 2.7739e-04
# Epoch 70/100
# 20/20 [==============================] - 6s 323ms/step - loss: 3.3276e-04 - val_loss: 2.7806e-04
# Epoch 71/100
# 20/20 [==============================] - 6s 303ms/step - loss: 3.5524e-04 - val_loss: 3.2959e-04
# Epoch 72/100
# 20/20 [==============================] - 6s 303ms/step - loss: 3.3366e-04 - val_loss: 2.6558e-04
# Epoch 73/100
# 20/20 [==============================] - 6s 294ms/step - loss: 3.5590e-04 - val_loss: 2.5541e-04
# Epoch 74/100
# 20/20 [==============================] - 6s 291ms/step - loss: 3.0940e-04 - val_loss: 2.8995e-04
# Epoch 75/100
# 20/20 [==============================] - 6s 293ms/step - loss: 3.0049e-04 - val_loss: 3.3315e-04
# Epoch 76/100
# 20/20 [==============================] - 6s 294ms/step - loss: 3.2861e-04 - val_loss: 2.6320e-04
# Epoch 77/100
# 20/20 [==============================] - 6s 292ms/step - loss: 3.4174e-04 - val_loss: 2.8215e-04
# Epoch 78/100
# 20/20 [==============================] - 6s 292ms/step - loss: 4.3135e-04 - val_loss: 3.1741e-04
# Epoch 79/100
# 20/20 [==============================] - 6s 293ms/step - loss: 3.0633e-04 - val_loss: 3.2882e-04
# Epoch 80/100
# 20/20 [==============================] - 6s 310ms/step - loss: 2.7679e-04 - val_loss: 3.1769e-04
# Epoch 81/100
# 20/20 [==============================] - 6s 294ms/step - loss: 3.0105e-04 - val_loss: 3.4401e-04
# Epoch 82/100
# 20/20 [==============================] - 6s 294ms/step - loss: 2.7751e-04 - val_loss: 3.1263e-04
# Epoch 83/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.8323e-04 - val_loss: 2.5287e-04
# Epoch 84/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.6848e-04 - val_loss: 2.6309e-04
# Epoch 85/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.6273e-04 - val_loss: 3.2231e-04
# Epoch 86/100
# 20/20 [==============================] - 6s 293ms/step - loss: 2.8466e-04 - val_loss: 3.4800e-04
# Epoch 87/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.6912e-04 - val_loss: 3.0261e-04
# Epoch 88/100
# 20/20 [==============================] - 6s 291ms/step - loss: 2.6606e-04 - val_loss: 2.3797e-04
# Epoch 89/100
# 20/20 [==============================] - 6s 297ms/step - loss: 2.5794e-04 - val_loss: 2.8010e-04
# Epoch 90/100
# 20/20 [==============================] - 6s 291ms/step - loss: 3.1708e-04 - val_loss: 5.0908e-04
# Epoch 91/100
# 20/20 [==============================] - 6s 292ms/step - loss: 4.7056e-04 - val_loss: 2.9047e-04
# Epoch 92/100
# 20/20 [==============================] - 6s 292ms/step - loss: 3.2631e-04 - val_loss: 2.6151e-04
# Epoch 93/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.3687e-04 - val_loss: 2.3068e-04
# Epoch 94/100
# 20/20 [==============================] - 6s 293ms/step - loss: 3.8579e-04 - val_loss: 3.3781e-04
# Epoch 95/100
# 20/20 [==============================] - 6s 300ms/step - loss: 2.5587e-04 - val_loss: 2.0512e-04
# Epoch 96/100
# 20/20 [==============================] - 6s 296ms/step - loss: 2.3103e-04 - val_loss: 2.3440e-04
# Epoch 97/100
# 20/20 [==============================] - 6s 293ms/step - loss: 2.3466e-04 - val_loss: 2.3269e-04
# Epoch 98/100
# 20/20 [==============================] - 6s 296ms/step - loss: 2.5054e-04 - val_loss: 2.4569e-04
# Epoch 99/100
# 20/20 [==============================] - 6s 291ms/step - loss: 2.3355e-04 - val_loss: 2.1905e-04
# Epoch 100/100
# 20/20 [==============================] - 6s 298ms/step - loss: 2.2934e-04 - val_loss: 2.5137e-04

# %%
# Prediction and checking performance matrix

train_predict = model.predict(X_train)
test_predict = model. predict(X_test)
# Out:
# 39/39 [==============================] - 4s 55ms/step
# 20/20 [==============================] - 1s 54ms/step

# %%
# transform to original form
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
# Now its time for calculating the rmse performance matrix.

print(math.sqrt(mean_squared_error(Y_train,train_predict)))
print(math.sqrt(mean_squared_error(Y_test,test_predict)))
# Out:
# 166.94068814077224
# 116.73878974432732

# %%
# Graph Plotting
look_back = 100

# %%
trainPredictPlot = np.empty_like(df2)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back : len(train_predict)+look_back,:] = train_predict

# %%
testPredictPlot = np.empty_like(df2)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back)*2 + 1 : len(df2) - 1,:] = test_predict

# %%
plt.plot(scaler.inverse_transform(df2))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
